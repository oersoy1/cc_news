# %%
import csv
import os
import pandas as pd
import re
import sys

from collections import Counter
from loguru import logger
from pathlib import Path
from time import time, strftime, gmtime

# %%
# Configuring the logger
config = {"handlers": [{"sink": sys.stdout,"colorize": True,
          "format": "<green>{time:YYYY-MM-DD HH:mm:ss}</green> | <level>{level: <8}</level> | <cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan> - <level>{message}</level>"}]}
logger.configure(**config)
# Out:
# [1]

# %%
# Data Folder
data_folder = Path.home() / 'Data' / 'cc_news'

# %%
start_time = time()
with open(data_folder / 'spark_output' / 'df_final.csv', 'r') as csv_file:
    reader = csv.DictReader(csv_file)
    keyword_counter = Counter()
    for i, row in enumerate(reader):
        keywords = row['keywords']
        if keywords != "" or keywords is not None:
            try:
                split_keywords = re.split('[,;-]', keywords)
            except TypeError:
                pass
            for k in split_keywords:
                if k != '' and len(k)>2:
                    keyword_counter.update({k.strip().lower(): 1})
elapsed = strftime("%H:%M:%S", gmtime(time() - start_time))
logger.info(f'It took {elapsed} to run this script!')
os.system("play /usr/share/sounds/sound-icons/trumpet-1.wav") # Beeps an alert. May not run on your machine
# Out:
# 2020-01-08 21:54:48 | INFO     | __main__:<module>:16 - It took 00:00:05 to run this script!
# 0

# %%
# Create a short list of main topic keywords that we will use as a lookup
main_topics = {("government / politics", "politics", "government", "us government news", "government news"): "politics",
               ("economics", "economy", "trade", "business", "company news","finance", "market reports",
                "stock", "stocks" "company", "companies", "tech", "technology",
                "mergers / acquisitions / takeovers", "corporate events", "equity markets",
                "international trade","equities markets", "markets", "market", "emerging market countries"): "business_economy",
               ("world","world news", "europe", "western europe","asia", "asia / pacific", 
                "africa","west africa","east africa", "southern africa", "european union"
                "latin america", "americas", "mid east", "middle east"): "world",
                ("entertainment","entertainment news", "celebrity", "gossip", "music"): "entertainment",
                ('sport', 'sports', 'league', 'game', 'soccer', 'basketball', 'football', 'games', 'score', 'scores', "nfl", "premier league"): "sports",
              }

# %%
start_time = time()
with open(data_folder / 'spark_output' / 'df_final.csv', 'r') as csv_file:
    reader = csv.DictReader(csv_file)
    counters = {"politics" : Counter(), 
                "world": Counter(),
                "business_economy":Counter(),
                'sports':Counter(),
                'entertainment':Counter(),
                'other': Counter()
               }
    
    exclude = ["news", 'local', "general news", "united states", "travel",
              "breaking news", "breaking", "major events", "major news", 
               "current events", "latest news", "current_news", "picture available", "pictures", "picture"]
    main_topic_kw = [k for key in main_topics.keys() for k in key] + exclude
    for row in reader:
        keywords = row['keywords']
        if keywords != "" or keywords is not None:
            try:
                split_keywords = re.split('[,;-]', keywords)
                split_keywords = [s.strip().lower() for s in split_keywords]
                for k, v in main_topics.items():
                    if len(set(split_keywords).intersection(set(k))) > 1:
                        for kw in split_keywords:
                            if kw != '' and len(kw)>2 and kw not in main_topic_kw:
                                counters[v].update({kw: 1})
                    else:
                        for kw in split_keywords:
                            if kw != '' and len(kw)>2 and kw not in main_topic_kw:
                                counters['other'].update({kw: 1})

            except TypeError:
                pass
    
elapsed = strftime("%H:%M:%S", gmtime(time() - start_time))
logger.info(f'It took {elapsed} to run this script!')
os.system("play /usr/share/sounds/sound-icons/trumpet-1.wav") # Beeps an alert. May not run on your machine
# Out:
# 2020-01-09 16:42:26 | INFO     | __main__:<module>:36 - It took 00:00:10 to run this script!
# 0

# %%
for k, counter in counters.items():
    print(k, counters[k].most_common(30), "\n")
# Out:
# politics [('usa', 209), ('diplomacy / foreign policy', 145), ('us house of representatives', 137), ('international / national security', 114), ('trump', 113), ('judicial process / court cases / court decisions', 113), ('impeachment', 107), ('donald trump', 104), ('us senate', 103), ('ukraine', 102), ('lawmaking', 101), ('crime / law / justice', 100), ('crime', 92), ('russia', 90), ('elections / voting', 64), ('presidential elections', 61), ('exclusive', 46), ('video', 45), ('nancy pelosi', 42), ('graphics', 41), ('stadium', 40), ('european union', 39), ('match', 38), ('biofuels', 36), ('region', 34), ('message', 32), ('health / medicine', 31), ('oil and gas (trbc)', 30), ('conflicts / war / peace', 30), ('joe biden', 30)]
#
# world [('united kingdom', 256), ('france', 162), ('european union', 152), ('china (prc)', 151), ('diplomacy / foreign policy', 151), ('germany', 145), ('financials (legacy)', 113), ('japan', 110), ('euro zone', 108), ('financials (trbc)', 104), ('italy', 104), ('judicial process / court cases / court decisions', 102), ('governance', 102), ('hong kong', 102), ('auto and truck manufacturers (trbc)', 100), ('cyclical consumer goods and services (trbc)', 100), ('deal', 99), ('banking and investment services (trbc)', 98), ('central / eastern europe', 96), ('legal and judicial affairs', 95), ('debt / fixed income markets', 85), ('business and finance', 84), ('crime / law / justice', 80), ('transportation (trbc)', 78), ('international / national security', 77), ('regulation', 75), ('automobiles / auto parts (legacy)', 75), ('automobiles and auto parts (trbc)', 75), ('nigeria', 74), ('labour / personnel', 74)]
#
# business_economy [('commerce', 155), ('china (prc)', 129), ('france', 113), ('financials (legacy)', 112), ('governance', 109), ('deal', 109), ('financials (trbc)', 107), ('united kingdom', 106), ('cyclical consumer goods and services (trbc)', 106), ('legal and judicial affairs', 97), ('hong kong', 96), ('regulation', 94), ('company', 93), ('banking and investment services (trbc)', 92), ('business and finance', 90), ('auto and truck manufacturers (trbc)', 90), ('japan', 88), ('italy', 86), ('debt / fixed income markets', 85), ('deals', 83), ('china', 78), ('reports', 77), ('content produced in bangalore', 76), ('nigeria', 73), ('south africa', 72), ('usa', 71), ('labour / personnel', 67), ('national government debt', 66), ('euro zone', 66), ('industrials (trbc)', 65)]
#
# sports [('team', 163), ('american football', 113), ('point', 89), ('rebound', 76), ('sky', 74), ('prep', 73), ('college', 70), ('win', 60), ('season', 60), ('lead', 56), ('assist', 52), ('stadium', 46), ('arsenal', 46), ('live', 44), ('liverpool', 44), ('coach', 43), ('steal', 39), ('player', 39), ('match', 39), ('message', 36), ('fixtures', 35), ('free throw', 34), ('school', 34), ('results', 34), ('region', 32), ('oklahoma city', 32), ('okc', 32), ('tournament', 30), ('barcelona', 29), ('video', 29)]
#
# entertainment [('bollywood news', 69), ('movies', 46), ('latest bollywood news', 33), ('bollywood gossip', 33), ('latest bollywood gossip', 33), ('latest bollywood headlines', 33), ('latest bollywood events', 33), ('bollywood news today', 33), ('blog', 33), ('bollywood', 29), ('arts', 21), ('rochester', 19), ('hollywood news', 18), ('events', 18), ('calendar', 18), ('new york', 18), ('alternative news', 18), ('journalism', 18), ('television news', 16), ('celebitchy', 15), ('celebrities', 15), ('famous', 15), ('royals', 15), ('royal', 15), ('liberal politics', 15), ('oscar', 15), ('pop culture', 15), ('post', 15), ('bitchy', 15), ('humor', 15)]
#
# other [('donald trump', 6322), ('crime', 5981), ('impeachment', 5155), ('law', 4611), ('christmas', 3501), ('police', 3453), ('india', 3279), ('commerce', 3254), ('stocks', 2939), ('work', 2926), ('china', 2856), ('education', 2741), ('company', 2661), ('criminal law', 2484), ('cnn', 2467), ('school', 2466), ('obituaries', 2456), ('food', 2319), ('trump', 2312), ('barcelona', 2214), ('state', 2194), ('weather', 2027), ('real madrid', 2018), ('health', 2001), ('christianity', 1968), ('congress', 1928), ('nancy pelosi', 1882), ('primera divisiã³n', 1870), ('video', 1853), ('african all stars', 1790)]

# %%
df_final = pd.read_csv(data_folder / 'spark_output' / 'df_final.csv')

# %%
def label_records_via_keywords(keywords):
    if keywords != "" or keywords is not None:
        try:
            split_keywords = re.split('[,;-]', keywords)
            split_keywords = [s.strip().lower() for s in split_keywords]
            for k, v in main_topics.items():
                if len(set(split_keywords).intersection(set(k))) > 1:
                    return v
        except:
            return None

# %%
df_final.head()
# Out:
#                                                  url         dom_cat  \
# 0  https://chicago.cbslocal.com/2019/12/18/man-st...          sports
# 1  http://www.releasewire.com/press-releases/rele...            news
# 2  https://www.kark.com/news/national-news/1-dead...            news
# 3  https://www.ii.co.uk/etfs/sg-wti-x2-daily-long...  financial_news
# 4  http://www.peicanada.com/island_deaths/frances...            news
#
#                                                title  \
# 0  Man Stabbed After His Granddaughter And Three ...
# 1  Commence Industrial CRM Achieves Sales Optimiz...
# 2  1 dead, 2 injured in Oregon shopping center st...
# 3  LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...
# 4    Frances Salsman | Island Deaths | peicanada.com
#
#                                          description  \
# 0  A man's granddaughter is one of four teens acc...
# 1                                                NaN
# 2  Multiple people were stabbed at the Murray Hil...
# 3  Real-time share price updates and latest news ...
# 4  SALSMAN, Frances (Fran) Townsend At the Prince...
#
#                                             keywords  \
# 0  grandfather, granddaughter, teen, teens, home ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       island_deaths, death_notices
#
#                                        news_keywords  \
# 0  grandfather, granddaughter, teen, teens, home ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       island_deaths, death_notices
#
#                                                 text
# 0  Man Stabbed After His Granddaughter And Three ...
# 1  Commence Industrial CRM Achieves Sales Optimiz...
# 2  1 dead, 2 injured in Oregon shopping center st...
# 3  LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...
# 4  Frances Salsman | Island Deaths | peicanada.co...

# %%
df_final['kw_label'] = df_final.apply(lambda row: label_records_via_keywords(row['keywords']), axis=1)

# %%
df_final[~df_final.kw_label.isna()]
# Out:
#                                                       url        dom_cat  \
# 64      https://www.nwitimes.com/news/local/govt-and-p...           news
# 199     https://www.news4jax.com/news/politics/2019/12...           news
# 302     https://www.reuters.com/article/us-basketball-...           news
# 309     https://www.reuters.com/article/us-usa-biofuel...           news
# 342     https://coed.com/2019/11/26/dallas-cowboys-hea...  entertainment
# ...                                                   ...            ...
# 163132  https://www.redandblack.com/sports/georgia-foo...           news
# 163221  https://6abc.com/sports/eagles-ready-to-take-o...           news
# 163319  https://madison.com/opinion/letters/coach-gard...           news
# 163328  https://qctimes.com/sports/high-school/basketb...           news
# 163413  https://www.redandblack.com/sports/georgia-foo...           news
#
#                                                     title  \
# 64      Visclosky set to vote today for both impeachme...
# 199     Sports betting's rapid expansion faces more te...
# 302     \n                Suns' Ayton begins second ac...
# 309     \n                White House says it is stick...
# 342     Dallas Cowboys Head Coaching Odds 2019: Who Wi...
# ...                                                   ...
# 163132  Georgia football signs 5-star outside lineback...
# 163221  Philadelphia Eagles ready to take on Cowboys, ...
# 163319  Coach Gard must right sinking ship -- Hal Wiss...
# 163328  Central DeWitt remains No. 1 in Area Fab 5 | H...
# 163413  Georgia football signs 4-star quarterback Cars...
#
#                                               description  \
# 64      U.S. Rep. Pete Visclosky will join the Democra...
# 199     The line for the ticket windows at a Rhode Isl...
# 302     Phoenix Suns big man Deandre Ayton is again in...
# 309     The Trump administration plans to stick with i...
# 342     Who will be the Dallas Cowboys head coach next...
# ...                                                   ...
# 163132  Mekhail Sherman signed his letter of intent to...
# 163221  "Embarrassing!" That's the word Carson Wentz, ...
# 163319  What’s going on with the Wisconsin men’s baske...
# 163328                                         AREA FAB 5
# 163413  The Georgia football team officially signed fo...
#
#                                                  keywords  \
# 64      , indiana, national-government, local-governme...
# 199                            Sports,politics,Government
# 302     US,BASKETBALL,NBA,PHX,AYTON,Bahamas,Americas,S...
# 309     US,USA,BIOFUELS,EXCLUSIVE,Biofuels,Advocacy Gr...
# 342         Sports,Sports,Betting Odds,dallas-cowboys,NFL
# ...                                                   ...
# 163132  mekhail sherman, linebacker, georgia, sport, b...
# 163221  Philadelphia eagles, eagles, nfl, football, Da...
# 163319  , letter to editor, commentary, greg gard, bas...
# 163328  , northeast, central dewitt, game, sport, albu...
# 163413  carson beck, sport, alabama, toby bullock, foo...
#
#                                             news_keywords  \
# 64      , indiana, national-government, local-governme...
# 199                                                   NaN
# 302     US;BASKETBALL;NBA;PHX;AYTON;Bahamas;Americas;S...
# 309     US;USA;BIOFUELS;EXCLUSIVE;Biofuels;Advocacy Gr...
# 342         Sports,Sports,Betting Odds,dallas-cowboys,NFL
# ...                                                   ...
# 163132  mekhail sherman, linebacker, georgia, sport, b...
# 163221                                                NaN
# 163319  , letter to editor, commentary, greg gard, bas...
# 163328  , northeast, central dewitt, game, sport, albu...
# 163413  carson beck, sport, alabama, toby bullock, foo...
#
#                                                      text  kw_label
# 64      Visclosky set to vote today for both impeachme...  politics
# 199     Sports betting's rapid expansion faces more te...  politics
# 302     Suns' Ayton begins second act after suspension...    sports
# 309     White House says it is sticking with 2020 biof...  politics
# 342     Dallas Cowboys Head Coaching Odds 2019: Who Wi...    sports
# ...                                                   ...       ...
# 163132  Georgia football signs 5-star outside lineback...    sports
# 163221  Philadelphia Eagles ready to take on Cowboys, ...    sports
# 163319  Coach Gard must right sinking ship -- Hal Wiss...    sports
# 163328  Central DeWitt remains No. 1 in Area Fab 5 | H...    sports
# 163413  Georgia football signs 4-star quarterback Cars...    sports
#
# [3669 rows x 8 columns]

# %%
# Sampling for inspection
df_final[df_final.kw_label=='sports'].sample(10)
# Out:
#                                                       url dom_cat  \
# 67187   https://www.wsls.com/sports/2019/12/18/introdu...    news
# 69872   https://www.wacotrib.com/sports/college/baylor...    news
# 47807   https://www.heraldandnews.com/sports/arizona-b...    news
# 149257  https://www.onenewspage.com/video/20191213/125...    news
# 16829   https://www.chroniclejournal.com/sports/nation...    news
# 129523  https://www.stwnewspress.com/sports/osu_sports...    news
# 47664   https://www.skysports.com/football/news/11670/...  sports
# 82183   https://www.hitc.com/en-gb/2019/12/18/do-repor...    news
# 80101   https://www.forbes.com/sites/mikeozanian/2019/...    news
# 17316   https://oklahoman.com/article/5650169/ou-at-cr...    news
#
#                                                     title  \
# 67187   Introducing your 2019 Coach and Player of the ...
# 69872   Defense key to Baylor men's No. 10 ranking | B...
# 47807   Arizona, Bumgarner complete deal | Sports | he...
# 149257  David Stern Hospitalized With Brain Hemorrhage...
# 16829   Aho, Staal score twice as the Hurricanes doubl...
# 129523  ORANGE PRATTLE: Why I was part of 4% not to vo...
# 47664   Arsenal hope Mikel Arteta will be head coach f...
# 82183   Report: Southampton want Champions League pair...
# 80101   The Worldâs Most Valuable Sports Empires: Wo...
# 17316   OU at Creighton men's basketball: Foul trouble...
#
#                                               description  \
# 67187   Local high school football greats were honored...
# 69872   Baylor has risen to No. 10 in the country behi...
# 47807   PHOENIX (AP) — The Arizona Diamondbacks have f...
# 149257  David Stern Hospitalized With Brain Hemorrhage...
# 16829   WINNIPEG - Sebastian Aho and Jordan Staal each...
# 129523  As an Oklahoma State beat writer, I know full ...
# 47664   Arsenal remain hopeful that Mikel Arteta will ...
# 82183   Joakim Maehle and Marin Pongracic could be hea...
# 80101   Sports owners with great brands have increasin...
# 17316   Oklahoma was down by eight points with 13:31 l...
#
#                                                  keywords  \
# 67187              Sports,High School,1st and 10,Football
# 69872   baylor, sport, basketball, bears show, mark vi...
# 47807   mlb baseball, arizona diamondbacks, madison bu...
# 149257  David Stern brain hemorrhage,basketball,sports...
# 16829   sports, carolina hurricanes, sebastian aho, po...
# 129523  jalen hurts, joe burrow, justin fields, sport,...
# 47664   Sky, Sports, Football, Premier League, Premier...
# 82183   saintsfc,cpfc,southampton fc,crystal palace fc...
# 80101   sports, nba, nfl, mlb, nhl, premier league, ml...
# 17316   oklahoma city,okc,Sports, College, Ou, Basketb...
#
#                                             news_keywords  \
# 67187                                                 NaN
# 69872   baylor, sport, basketball, bears show, mark vi...
# 47807   mlb baseball, arizona diamondbacks, madison bu...
# 149257                                                NaN
# 16829   sports, carolina hurricanes, sebastian aho, po...
# 129523  jalen hurts, joe burrow, justin fields, sport,...
# 47664                                                 NaN
# 82183   saintsfc,cpfc,southampton fc,crystal palace fc...
# 80101   sports, nba, nfl, mlb, nhl, premier league, ml...
# 17316   oklahoma city,okc,Sports, College, Ou, Basketb...
#
#                                                      text kw_label
# 67187   Introducing your 2019 Coach and Player of the ...   sports
# 69872   Defense key to Baylor men's No. 10 ranking | B...   sports
# 47807   Arizona, Bumgarner complete deal | Sports | he...   sports
# 149257  David Stern Hospitalized With Brain Hemorrhage...   sports
# 16829   Aho, Staal score twice as the Hurricanes doubl...   sports
# 129523  ORANGE PRATTLE: Why I was part of 4% not to vo...   sports
# 47664   Arsenal hope Mikel Arteta will be head coach f...   sports
# 82183   Report: Southampton want Champions League pair...   sports
# 80101   The Worldâs Most Valuable Sports Empires: Wo...   sports
# 17316   OU at Creighton men's basketball: Foul trouble...   sports

# %%
df_final.iloc[47622].text
# Out:
# "Cameroon-Israel Relations - Ambassador Granted Farewell Audience - allAfrica.com Countries All Countries Algeria Angola Benin Botswana Burkina Faso Burundi Cameroon Cape Verde Central African Republic Chad Comoros Congo-Brazzaville Congo-Kinshasa Cote d'Ivoire Djibouti Egypt Equatorial Guinea Eritrea Ethiopia Gabon Gambia Ghana Guinea Guinea Bissau Kenya Lesotho Liberia Libya Madagascar Malawi Mali Mauritania Mauritius Morocco Mozambique Namibia Niger Nigeria Rwanda Senegal Seychelles Sierra Leone Somalia South Africa South Sudan Sudan Swaziland São Tomé and Príncipe Tanzania Togo Tunisia Uganda Western Sahara Zambia Zimbabwe Africa-Wide Central Africa Central Africa Home Angola Burundi Cameroon Central African Republic Chad Congo-Brazzaville Congo-Kinshasa Equatorial Guinea Gabon Rwanda São Tomé and Príncipe East Africa East Africa Home Burundi Comoros Djibouti Eritrea Ethiopia Kenya Madagascar Mauritius Rwanda Seychelles Somalia South Sudan Sudan Tanzania Uganda North Africa North Africa Home Algeria Egypt Libya Morocco Tunisia Western Sahara Southern Africa Southern Africa Home Angola Botswana Lesotho Malawi Mozambique Namibia South Africa Swaziland Zambia Zimbabwe West Africa West Africa Home Benin Burkina Faso Cameroon Cape Verde Cote d'Ivoire Gambia Ghana Guinea Guinea Bissau Liberia Mali Mauritania Niger Nigeria Senegal Sierra Leone São Tomé and Príncipe Togo Topics All Topics AIDS Agribusiness Aid and Assistance Arms and Armies Asia, Australia, and Africa Athletics Banking Book Reviews Books Business Capital Flows Children Climate Commodities Company Conflict Construction Corruption Currencies Debt Ebola Ecotourism Education Energy Entertainment Environment Europe and Africa External Relations Food and Agriculture Game Parks Governance Health Human Rights ICT Infrastructure Innovation International Organisations Investment Labour Land and Rural Issues Latin America and Africa Legal Affairs Malaria Manufacturing Media Middle East and Africa Migration Mining Music Music Reviews NCDs NGO Nutrition Oceans Olympics Peacekeeping Petroleum Polio Pregnancy and Childbirth Privatization Refugees Religion Science Soccer Sport Stock Markets Sustainable Development Terrorism Trade Transport Travel Tuberculosis U.S., Canada and Africa Urban Issues Water Wildlife Women World Cup Entertainment Entertainment Home Book Reviews Books Music Music Reviews Business Business Home Agribusiness Banking Capital Flows Commodities Company Construction Currencies Debt Energy I"

# %%
df_final.head()
# Out:
#                                                  url         dom_cat  \
# 0  https://chicago.cbslocal.com/2019/12/18/man-st...          sports
# 1  http://www.releasewire.com/press-releases/rele...            news
# 2  https://www.kark.com/news/national-news/1-dead...            news
# 3  https://www.ii.co.uk/etfs/sg-wti-x2-daily-long...  financial_news
# 4  http://www.peicanada.com/island_deaths/frances...            news
#
#                                                title  \
# 0  Man Stabbed After His Granddaughter And Three ...
# 1  Commence Industrial CRM Achieves Sales Optimiz...
# 2  1 dead, 2 injured in Oregon shopping center st...
# 3  LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...
# 4    Frances Salsman | Island Deaths | peicanada.com
#
#                                          description  \
# 0  A man's granddaughter is one of four teens acc...
# 1                                                NaN
# 2  Multiple people were stabbed at the Murray Hil...
# 3  Real-time share price updates and latest news ...
# 4  SALSMAN, Frances (Fran) Townsend At the Prince...
#
#                                             keywords  \
# 0  grandfather, granddaughter, teen, teens, home ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       island_deaths, death_notices
#
#                                        news_keywords  \
# 0  grandfather, granddaughter, teen, teens, home ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                       island_deaths, death_notices
#
#                                                 text kw_label
# 0  Man Stabbed After His Granddaughter And Three ...     None
# 1  Commence Industrial CRM Achieves Sales Optimiz...     None
# 2  1 dead, 2 injured in Oregon shopping center st...     None
# 3  LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...     None
# 4  Frances Salsman | Island Deaths | peicanada.co...     None

# %%
df_final['text'] = df_final.text.fillna('')

# %%
def make_printable(string):
    """
    Clean up Non-ASCII characters.

    Replace non-printable characters in a string.
    """
    no_print_trans_table = ''.join([chr(i) for i in range(128)] + [' '] * 128)
    
    try:
        trans = string.translate(no_print_trans_table)
    except AttributeError:
        trans = ""
    return trans

# %%
df_final['text'] = df_final["text"].apply(lambda text: make_printable(text))

# %%
df_final
# Out:
#                                                       url         dom_cat  \
# 0       https://chicago.cbslocal.com/2019/12/18/man-st...          sports
# 1       http://www.releasewire.com/press-releases/rele...            news
# 2       https://www.kark.com/news/national-news/1-dead...            news
# 3       https://www.ii.co.uk/etfs/sg-wti-x2-daily-long...  financial_news
# 4       http://www.peicanada.com/island_deaths/frances...            news
# ...                                                   ...             ...
# 163428  https://www.bakingbusiness.com/articles/49996-...  financial_news
# 163429  https://www.fark.com/comments/10653287?utm_sou...            news
# 163430  https://www.mygrandeprairienow.com/65144/local...            news
# 163431  https://www.thehollywoodgossip.com/slideshows/...   entertainment
# 163432  https://www.hometownsource.com/county_news_rev...            news
#
#                                                     title  \
# 0       Man Stabbed After His Granddaughter And Three ...
# 1       Commence Industrial CRM Achieves Sales Optimiz...
# 2       1 dead, 2 injured in Oregon shopping center st...
# 3       LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...
# 4         Frances Salsman | Island Deaths | peicanada.com
# ...                                                   ...
# 163428  Dairy Farmers of America merges ingredients bu...
# 163429  FARK.com:  (10653287) You can now watch the vi...
# 163430  Local man hoping to make holidays special by h...
# 163431  90 Day Fiance Before The 90 Days: Trailer Teas...
# 163432  Kenneth "Ken" Edwin Holmstrom | Obituaries | h...
#
#                                               description  \
# 0       A man's granddaughter is one of four teens acc...
# 1                                                     NaN
# 2       Multiple people were stabbed at the Murray Hil...
# 3       Real-time share price updates and latest news ...
# 4       SALSMAN, Frances (Fran) Townsend At the Prince...
# ...                                                   ...
# 163428  KANSAS CITY â Dairy Farmers of America (D.F....
# 163429  Humorous views on interesting, bizarre and amu...
# 163430                                                NaN
# 163431  90 Day Fiance: Before The 90 Days just release...
# 163432  Kenneth Holmstrom of Harris passed away Saturd...
#
#                                                  keywords  \
# 0       grandfather, granddaughter, teen, teens, home ...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                            island_deaths, death_notices
# ...                                                   ...
# 163428  baking business, Baking & Snack, baking and sn...
# 163429  Fark, Fark.com, Drew Curtis, News, Community N...
# 163430                                                NaN
# 163431                                                NaN
# 163432                                         obituaries
#
#                                             news_keywords  \
# 0       grandfather, granddaughter, teen, teens, home ...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                            island_deaths, death_notices
# ...                                                   ...
# 163428                                                NaN
# 163429                                                NaN
# 163430                                                NaN
# 163431                                                NaN
# 163432                                         obituaries
#
#                                                      text kw_label
# 0       Man Stabbed After His Granddaughter And Three ...     None
# 1       Commence Industrial CRM Achieves Sales Optimiz...     None
# 2       1 dead, 2 injured in Oregon shopping center st...     None
# 3       LSE:SG30 ETF Share Price | SG WTI X2 Daily Lon...     None
# 4       Frances Salsman | Island Deaths | peicanada.co...     None
# ...                                                   ...      ...
# 163428  Dairy Farmers of America merges ingredients bu...     None
# 163429  FARK.com: (10653287) You can now watch the vid...     None
# 163430  Local man hoping to make holidays special by h...     None
# 163431  90 Day Fiance Before The 90 Days: Trailer Teas...     None
# 163432  Kenneth "Ken" Edwin Holmstrom | Obituaries | h...     None
#
# [163433 rows x 8 columns]

# %%
df_final.text.sample(1).item()
# Out:
# /home/ozan/anaconda3/envs/cc_news_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: `item` has been deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# 'Lawsuit: Apple, Microsoft profit from child cobalt miners | KRQE News 13 Skip to content KRQE News 13 Albuquerque 21  Sponsored By Search Primary Menu Live/Video Video Center Live Broadcast KRQE Live CBSN Live Stream News Top Stories Local News Larry Barker On Special Assignment Politics – Government Elections Election Results Washington D.C. Bureau U.S. News World Entertainment Don’t Miss Weird Wildfires BorderReport.com Top Stories Company believes to have captured essence of New Mexico in candle As House convenes on impeachment, Trump declares disbelief Verizon reportedly experiencing nationwide outage Survey: Average American will be involved in 12 arguments during holiday travel Weather Radar VIDEO Full Forecast Closings & Delays Alerts Map Center Ski Conditions Winds Albuquerque Rio Rancho East Mountains/Edgewood Santa Fe/Northern Mtns Farmington/Northwest NM Durango/Southern CO Las Vegas Roswell Roads/Traffic Live Traffic Map & Cameras Road Weather Albuquerque I-40 Cameras Albuquerque I-25 Cameras Paseo/Coors/Rio Rancho Bernalillo/550 I-40 Corridor I-25/Northern New Mexico I-25/Southern New Mexico KRQE+ The Series Community Reports Data Reports Interactive Multimedia Photo Galleries Local Events Balloon Fiesta Hispanic Heritage Month Veterans Voices Contests Quizzes Sports Local Sports High School Sports 2019 ProFootball Challenge The Big Game Always On ReportIt! Submit a ReportIt! Report It Photos More New Mexico Living FOX New Mexico New Mexico CW – My50TV —————- About Us Advertise with Us Contact Us Email Newsletters Meet The Team Internship Jobs/Career Opportunities KRQE Cares KRQE Digital Mobile Apps Text Alerts TV Schedule Search Search Search Live Now Live Now House votes on impeachment of President Donald Trump Lawsuit: Apple, Microsoft profit from child cobalt miners Business by: ASHRAF KHALIL, Associated Press Posted: Dec 17, 2019 / 01:44 PM MST / Updated: Dec 17, 2019 / 03:11 PM MST WASHINGTON (AP) — A new lawsuit accuses several of the world’s largest technology firms of knowingly profiting from children laboring under brutal conditions in African cobalt mines. The suit, filed this week in Washington by the nongovernmental organization International Rights Advocates, seeks damages from Apple, Dell, Microsoft, Tesla and Alphabet, the parent company of Google. Cobalt is an essential element in the rechargeable lithium batteries that fuel many electronic devices. The rise of smartphones in the past 20 years has created a large demand for th'

# %%
df_final.kw_label.value_counts()
# Out:
# business_economy    1438
# sports              1199
# politics             479
# world                395
# entertainment        158
# Name: kw_label, dtype: int64

# %%
df_final[df_final.kw_label=='sports'].sample(10)
# Out:
#                                                       url dom_cat  \
# 72154   https://santamariatimes.com/sports/high-school...    news
# 121816  https://wcfcourier.com/daniel-jackson/article_...    news
# 71815   https://www.hitc.com/en-gb/2019/12/18/great-im...    news
# 71903   https://www.hitc.com/en-gb/2019/12/18/report-t...    news
# 17499   https://elkodaily.com/sports/local/spartans-ta...    news
# 51724   https://www.skysports.com/football/news/11095/...  sports
# 88344   https://www.omaha.com/sports/scoreboard/thursd...    news
# 67048   https://www.somdnews.com/enterprise/sports/new...    news
# 120442  https://santamariatimes.com/jamarri-jackson-db...    news
# 41929   https://www.hitc.com/en-gb/2019/12/18/should-l...    news
#
#                                                     title  \
# 72154   Santa Ynez boys soccer hands Santa Maria its 1...
# 121816                 Daniel Jackson |  | wcfcourier.com
# 71815   'Great imagination, great feet': Jamie Redknap...
# 71903   Report: The January transfer budget Arsenal wi...
# 17499   Spartans take 31st of 107 teams at RTOC | Loca...
# 51724   Family of England fan who died in Bulgaria sti...
# 88344     Thursday's Area Events | Scoreboard | omaha.com
# 67048   St. Mary's College of Maryland basketball team...
# 120442      Jamarri Jackson | DB |  | santamariatimes.com
# 41929        Should Leeds look at Tottenham's Juan Foyth?
#
#                                               description  \
# 72154   The Santa Ynez Pirates scored early Tuesday ni...
# 121816                                     Daniel Jackson
# 71815   Liverpool's youngsters lost 5-0 at Aston Villa...
# 71903   Arsenal are expected to announce the appointme...
# 17499   Facing the ultimate competition at the Reno To...
# 51724   The family of an England supporter who died in...
# 88344                         BOYS HIGH SCHOOL BASKETBALL
# 67048              Women’s basketball wins third straight
# 120442                                             Signed
# 41929   The Tottenham Hotspur defender was linked with...
#
#                                                  keywords  \
# 72154   , local-sports, prep-sports, soccer, sports, s...
# 121816  , daniel jackson, cyclone, sport, pass, score,...
# 71815   liverpool fc,premier league,jamie redknapp,har...
# 71903    arsenal fc,afc,premier league,mikel arteta,sport
# 17499   , spring creek spartans, sports, wrestling, re...
# 51724      News,Football,Sky,Sports,Sky Sports,sport,news
# 88344   omaha, sport, basketball, malcolm, johnson cou...
# 67048   "st. marys college of maryland, mens basketbal...
# 120442  , tackle, jackson, sport, norcal db, san mateo...
# 41929   leeds united fc,tottenham hotspur fc,premier l...
#
#                                             news_keywords  \
# 72154   , local-sports, prep-sports, soccer, sports, s...
# 121816  , daniel jackson, cyclone, sport, pass, score,...
# 71815   liverpool fc,premier league,jamie redknapp,har...
# 71903    arsenal fc,afc,premier league,mikel arteta,sport
# 17499   , spring creek spartans, sports, wrestling, re...
# 51724                                                 NaN
# 88344   omaha, sport, basketball, malcolm, johnson cou...
# 67048   "st. marys college of maryland, mens basketbal...
# 120442  , tackle, jackson, sport, norcal db, san mateo...
# 41929   leeds united fc,tottenham hotspur fc,premier l...
#
#                                                      text kw_label
# 72154   Santa Ynez boys soccer hands Santa Maria its 1...   sports
# 121816  Daniel Jackson | | wcfcourier.com Facebook Twi...   sports
# 71815   'Great imagination, great feet': Jamie Redknap...   sports
# 71903   Report: The January transfer budget Arsenal wi...   sports
# 17499   Spartans take 31st of 107 teams at RTOC | Loca...   sports
# 51724   Family of England fan who died in Bulgaria sti...   sports
# 88344   Thursday's Area Events | Scoreboard | omaha.co...   sports
# 67048   St. Mary's College of Maryland basketball team...   sports
# 120442  Jamarri Jackson | DB | | santamariatimes.com F...   sports
# 41929   Should Leeds look at Tottenham's Juan Foyth? S...   sports

# %%
from sklearn.model_selection import train_test_split
train, dev = train_test_split(df_final[~df_final.kw_label.isna()], test_size=0.1, random_state=42)

# %%
train.kw_label.value_counts()
# Out:
# business_economy    1300
# sports              1085
# politics             424
# world                349
# entertainment        144
# Name: kw_label, dtype: int64

# %%
train = pd.DataFrame({'id': range(len(train.index)),
                          'label': train["kw_label"],
                          'alpha': ['a'] * train.shape[0],
                          'text': train["text"]
                          })
    
dev = pd.DataFrame({'id': range(len(dev.index)),
                    'label': dev['kw_label'],
                    'alpha': ['a'] * dev.shape[0],
                    'text': dev["text"]
                    })

# %%
file_path = Path.home() / 'Data' / 'cc_news' / 'model_input'
if not file_path.is_dir():
    Path.mkdir(file_path, parents=True, exist_ok=True)
    
train.to_csv(file_path / 'train.tsv', sep='\t', header=False, index=False)
dev.to_csv(file_path / 'dev.tsv', sep='\t', header=False, index=False)

# %%
unlabeled = df_final[df_final.kw_label.isna()]
unlabeled = pd.DataFrame({'id': range(len(df_final)),
                            'text': df_final['text']
                          })

# %%
# Save unlabeled documents
unlabeled.to_csv(file_path / 'unlabeled.tsv', sep='\t', header=False, index=False)

# %%
df_final.kw_label.unique().tolist()
# Out:
# [None, 'politics', 'sports', 'business_economy', 'world', 'entertainment']
